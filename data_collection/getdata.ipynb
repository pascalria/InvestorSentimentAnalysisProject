# %%
import requests
from bs4 import BeautifulSoup
import time
import random
import csv

# %%
# # 东方财富创业板指
# url = "https://guba.eastmoney.com/list,zssz399006,f.html"

# # 浏览器标识
# headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36 Edg/114.0.1823.82'}

# r = requests.get(url, headers=headers)
# print(r.apparent_encoding)
# r.encoding = r.apparent_encoding
# text1 = r.text;print(text1)

# %%
def get_batch(offset):

    PAGES = 35
    real = offset*PAGES
    
    data_list = list()
    readl = list()
    authorl = list()
    titlel = list()
    timel = list()

    for i in range(real, PAGES+real):

        if i==0:
            url = "https://guba.eastmoney.com/list,zssz399006,f.html"
        else:
            url = "http://guba.eastmoney.com/list,zssz399006,f_"+str(i+1)+".html"
        
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36 Edg/114.0.1823.82'}       #模拟电脑端浏览器登陆，如果不写的话有些网页进不去
        request = requests.get(url, headers=headers)

        # print(request.apparent_encoding)

        request.encoding = request.apparent_encoding

        text = request.text

        soup = BeautifulSoup(text, 'html.parser')

        readl.extend([read.text for read in soup.find_all('div', class_='read')])
        authorl.extend([author.text for author in soup.find_all('div', class_='author')])
        titlel.extend([title.text for title in soup.find_all('div', class_='title')])
        timel.extend([title.text for title in soup.find_all('div', class_='update')])

        # elements_read = soup.find_all('div', class_='read')

        # elements_author = soup.find_all('div', class_='author')

        # elements_title = soup.find_all('div', class_='title')

        # readl.extend(elements_read)
        # authorl.extend(elements_author)
        # titlel.extend(elements_title)

        time.sleep(random.randint(1,5)) 

    data_list = [timel, readl, authorl, titlel]
    print('batch ' + str(offset+1) + 'done')

    return data_list

# %%
def tocsv(offset, data_list):

    filename = 'request' + str(offset) + '.csv'

    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Upload Time', 'Read', 'Author', 'Title'])
        for row in zip(*data_list):
            writer.writerow(row)

# %%
for i in range(58,280):
    data = get_batch(i)
    tocsv(i, data)
    time.sleep(600)
# Out:
# batch 59done
# batch 60done
# batch 61done
# batch 62done
# batch 63done
# batch 64done
# batch 65done
# batch 66done
# batch 67done
# batch 68done
# batch 69done
# batch 70done
# batch 71done
# batch 72done
# batch 73done
# batch 74done
# batch 75done
# batch 76done
# batch 77done
# batch 78done
# batch 79done
# batch 80done
# batch 81done
# batch 82done
# batch 83done
# batch 84done
# batch 85done
# batch 86done
# batch 87done
# batch 88done
# batch 89done
# batch 90done
# batch 91done
# batch 92done
# batch 93done
# batch 94done
# batch 95done
# batch 96done
# batch 97done
# batch 98done
# batch 99done
# batch 100done
# batch 101done
# batch 102done
# batch 103done
# batch 104done
# batch 105done
# batch 106done
# batch 107done
# batch 108done
# batch 109done
# batch 110done
# batch 111done
# batch 112done
# batch 113done
# batch 114done
# batch 115done
# batch 116done
# batch 117done
# batch 118done
# batch 119done
# batch 120done
# batch 121done
# batch 122done
# batch 123done
# batch 124done
# batch 125done
# batch 126done
# batch 127done
# batch 128done
# batch 129done
# batch 130done
# batch 131done
# batch 132done
# batch 133done
# batch 134done
# batch 135done
# batch 136done
# batch 137done
# batch 138done
# batch 139done
# batch 140done
# batch 141done
# batch 142done
# batch 143done
# batch 144done
# batch 145done
# batch 146done
# batch 147done
# batch 148done
# batch 149done
# batch 150done
# batch 151done
# batch 152done
# batch 153done
# batch 154done
# batch 155done
# batch 156done
# batch 157done
# batch 158done
# batch 159done
# batch 160done
# batch 161done
# batch 162done
# batch 163done
# batch 164done
# batch 165done
# batch 166done
# batch 167done
# batch 168done
# batch 169done
# batch 170done
# batch 171done
# batch 172done
# batch 173done
# batch 174done
# batch 175done
# batch 176done
# batch 177done
# batch 178done
# batch 179done
# batch 180done
# batch 181done
# batch 182done
# batch 183done
# batch 184done
# batch 185done
# batch 186done
# batch 187done
# batch 188done
# batch 189done
# batch 190done
# batch 191done
# batch 192done
# batch 193done
# batch 194done
# batch 195done
# batch 196done
# batch 197done
# batch 198done
# batch 199done
# batch 200done
# batch 201done
# batch 202done
# batch 203done
# batch 204done
# batch 205done
# batch 206done
# batch 207done
# batch 208done
# batch 209done
# batch 210done
# batch 211done
# batch 212done
# batch 213done
# batch 214done
# batch 215done
# batch 216done
# batch 217done
# batch 218done
# batch 219done
# batch 220done
# batch 221done
# batch 222done
# batch 223done
# batch 224done
# batch 225done
# batch 226done
# batch 227done
# batch 228done
# batch 229done
# batch 230done
# batch 231done
# batch 232done
# batch 233done
# batch 234done
# batch 235done
# batch 236done
# batch 237done
# batch 238done
# batch 239done
# batch 240done
# batch 241done
# batch 242done
# batch 243done
# batch 244done
# batch 245done
# batch 246done
# batch 247done
# batch 248done
# batch 249done
# batch 250done
# batch 251done
# batch 252done
# batch 253done
# batch 254done
# batch 255done
# batch 256done
# batch 257done
# batch 258done
# batch 259done
# batch 260done
# batch 261done
# batch 262done
# batch 263done
# batch 264done
# batch 265done
# batch 266done
# batch 267done
# batch 268done
# batch 269done
# batch 270done
# batch 271done
# batch 272done
# batch 273done
# batch 274done
# batch 275done
# batch 276done
# batch 277done
# batch 278done
# batch 279done
# batch 280done
